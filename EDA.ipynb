# %% [markdown]
# ## 1. Descargar la base de datos proporcionada en el formato de preferencia
# ## 2. Importar las librerías necesarias:

# %%
import pandas as pd
import numpy as np
import plotly.express as px

df = pd.read_excel('./data/data.xlsx', sheet_name='Base dsp-analytics-daily')
print(df.shape)
df.head()
# Out:
# (4004, 12)
#   RETAIL CATEGORIA       Date  Impressions  Clicks     CTR  Unique Visitors  \
# 0     BA    Cremas 2023-07-01         2386      14  0.0059           2391.0
# 1     BA    Cremas 2023-07-02         3423      17  0.0050           3319.0
# 2     BA    Cremas 2023-07-03         4241      17  0.0040           4242.0
# 3     BA    Cremas 2023-07-04         3947      20  0.0051           3913.0
# 4     BA    Cremas 2023-07-05         3697      19  0.0051           3707.0
#
#    Frequency   Spend  Units   Sales   ROAS
# 0     0.9979  134.40     13   405.0   3.01
# 1     1.0313  163.20     17   561.5   3.44
# 2     0.9998  136.32     13   427.5   3.14
# 3     1.0087  153.60      8   272.0   1.77
# 4     0.9973  105.72     21  3903.0  36.92

# %% [markdown]
# #### Se dividen las variables cunatitativas de las cualitativas

# %%
cualitative = ['RETAIL', 'CATEGORIA']
cuantitive = [i for i in df.columns if i not in cualitative and i != "Date"]
print(cuantitive)
# Out:
# ['Impressions', 'Clicks', 'CTR', 'Unique Visitors', 'Frequency', 'Spend', 'Units', 'Sales', 'ROAS']

# %% [markdown]
# ## 3. Limpiar y transformar los datos:

# %%
df.describe().T.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9126b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9126b_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_9126b_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_9126b_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_9126b_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_9126b_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_9126b_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_9126b_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_9126b_level0_col7" class="col_heading level0 col7" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9126b_level0_row0" class="row_heading level0 row0" >Date</th>
#       <td id="T_9126b_row0_col0" class="data row0 col0" >4004</td>
#       <td id="T_9126b_row0_col1" class="data row0 col1" >2023-05-03 17:52:05.274725120</td>
#       <td id="T_9126b_row0_col2" class="data row0 col2" >2023-01-01 00:00:00</td>
#       <td id="T_9126b_row0_col3" class="data row0 col3" >2023-03-11 00:00:00</td>
#       <td id="T_9126b_row0_col4" class="data row0 col4" >2023-05-10 00:00:00</td>
#       <td id="T_9126b_row0_col5" class="data row0 col5" >2023-06-28 00:00:00</td>
#       <td id="T_9126b_row0_col6" class="data row0 col6" >2023-08-11 00:00:00</td>
#       <td id="T_9126b_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row1" class="row_heading level0 row1" >Impressions</th>
#       <td id="T_9126b_row1_col0" class="data row1 col0" >4004.000000</td>
#       <td id="T_9126b_row1_col1" class="data row1 col1" >3181.110390</td>
#       <td id="T_9126b_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_9126b_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_9126b_row1_col4" class="data row1 col4" >1049.000000</td>
#       <td id="T_9126b_row1_col5" class="data row1 col5" >3820.500000</td>
#       <td id="T_9126b_row1_col6" class="data row1 col6" >133758.000000</td>
#       <td id="T_9126b_row1_col7" class="data row1 col7" >6496.049136</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row2" class="row_heading level0 row2" >Clicks</th>
#       <td id="T_9126b_row2_col0" class="data row2 col0" >4004.000000</td>
#       <td id="T_9126b_row2_col1" class="data row2 col1" >64.187812</td>
#       <td id="T_9126b_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_9126b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_9126b_row2_col4" class="data row2 col4" >25.000000</td>
#       <td id="T_9126b_row2_col5" class="data row2 col5" >75.000000</td>
#       <td id="T_9126b_row2_col6" class="data row2 col6" >2083.000000</td>
#       <td id="T_9126b_row2_col7" class="data row2 col7" >120.062119</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row3" class="row_heading level0 row3" >CTR</th>
#       <td id="T_9126b_row3_col0" class="data row3 col0" >4004.000000</td>
#       <td id="T_9126b_row3_col1" class="data row3 col1" >0.022348</td>
#       <td id="T_9126b_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_9126b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_9126b_row3_col4" class="data row3 col4" >0.015700</td>
#       <td id="T_9126b_row3_col5" class="data row3 col5" >0.030700</td>
#       <td id="T_9126b_row3_col6" class="data row3 col6" >0.500000</td>
#       <td id="T_9126b_row3_col7" class="data row3 col7" >0.028466</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row4" class="row_heading level0 row4" >Unique Visitors</th>
#       <td id="T_9126b_row4_col0" class="data row4 col0" >2843.000000</td>
#       <td id="T_9126b_row4_col1" class="data row4 col1" >2073.557861</td>
#       <td id="T_9126b_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_9126b_row4_col3" class="data row4 col3" >441.500000</td>
#       <td id="T_9126b_row4_col4" class="data row4 col4" >1158.000000</td>
#       <td id="T_9126b_row4_col5" class="data row4 col5" >2348.500000</td>
#       <td id="T_9126b_row4_col6" class="data row4 col6" >126706.000000</td>
#       <td id="T_9126b_row4_col7" class="data row4 col7" >5207.270286</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row5" class="row_heading level0 row5" >Frequency</th>
#       <td id="T_9126b_row5_col0" class="data row5 col0" >2843.000000</td>
#       <td id="T_9126b_row5_col1" class="data row5 col1" >2.232768</td>
#       <td id="T_9126b_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_9126b_row5_col3" class="data row5 col3" >1.496550</td>
#       <td id="T_9126b_row5_col4" class="data row5 col4" >1.982800</td>
#       <td id="T_9126b_row5_col5" class="data row5 col5" >2.820500</td>
#       <td id="T_9126b_row5_col6" class="data row5 col6" >8.418800</td>
#       <td id="T_9126b_row5_col7" class="data row5 col7" >0.956514</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row6" class="row_heading level0 row6" >Spend</th>
#       <td id="T_9126b_row6_col0" class="data row6 col0" >4004.000000</td>
#       <td id="T_9126b_row6_col1" class="data row6 col1" >643.133229</td>
#       <td id="T_9126b_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_9126b_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_9126b_row6_col4" class="data row6 col4" >274.000000</td>
#       <td id="T_9126b_row6_col5" class="data row6 col5" >802.850000</td>
#       <td id="T_9126b_row6_col6" class="data row6 col6" >12721.000000</td>
#       <td id="T_9126b_row6_col7" class="data row6 col7" >1068.795755</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row7" class="row_heading level0 row7" >Units</th>
#       <td id="T_9126b_row7_col0" class="data row7 col0" >4004.000000</td>
#       <td id="T_9126b_row7_col1" class="data row7 col1" >97.476024</td>
#       <td id="T_9126b_row7_col2" class="data row7 col2" >-1.000000</td>
#       <td id="T_9126b_row7_col3" class="data row7 col3" >9.000000</td>
#       <td id="T_9126b_row7_col4" class="data row7 col4" >28.000000</td>
#       <td id="T_9126b_row7_col5" class="data row7 col5" >79.250000</td>
#       <td id="T_9126b_row7_col6" class="data row7 col6" >3701.000000</td>
#       <td id="T_9126b_row7_col7" class="data row7 col7" >240.470749</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row8" class="row_heading level0 row8" >Sales</th>
#       <td id="T_9126b_row8_col0" class="data row8 col0" >4004.000000</td>
#       <td id="T_9126b_row8_col1" class="data row8 col1" >8878.259888</td>
#       <td id="T_9126b_row8_col2" class="data row8 col2" >-262.990000</td>
#       <td id="T_9126b_row8_col3" class="data row8 col3" >560.645000</td>
#       <td id="T_9126b_row8_col4" class="data row8 col4" >1739.500000</td>
#       <td id="T_9126b_row8_col5" class="data row8 col5" >5787.375000</td>
#       <td id="T_9126b_row8_col6" class="data row8 col6" >854804.910000</td>
#       <td id="T_9126b_row8_col7" class="data row8 col7" >30143.257392</td>
#     </tr>
#     <tr>
#       <th id="T_9126b_level0_row9" class="row_heading level0 row9" >ROAS</th>
#       <td id="T_9126b_row9_col0" class="data row9 col0" >4004.000000</td>
#       <td id="T_9126b_row9_col1" class="data row9 col1" >7.549788</td>
#       <td id="T_9126b_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_9126b_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_9126b_row9_col4" class="data row9 col4" >3.420000</td>
#       <td id="T_9126b_row9_col5" class="data row9 col5" >7.162500</td>
#       <td id="T_9126b_row9_col6" class="data row9 col6" >594.400000</td>
#       <td id="T_9126b_row9_col7" class="data row9 col7" >21.235721</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Se recalcula el CTR con la siguiente formula
# $$
# \text{CTR} = \frac{\text{Clics}}{\text{Impresiones}}
# $$

# %%
df["CTR"] = df.apply(lambda x: x["Clicks"] / x["Impressions"] if x["Impressions"] != 0 else 0, axis=1)
print(df["Impressions"].isna().sum())
print(df["Clicks"].isna().sum())
print(df["CTR"].isna().sum())
df["CTR"].describe()
# Out:
# 0
# 0
# 0
# count    4004.000000
# mean        0.022348
# std         0.028466
# min         0.000000
# 25%         0.000000
# 50%         0.015740
# 75%         0.030655
# max         0.500000
# Name: CTR, dtype: float64

# %%
px.histogram(df, x = "CTR")

# %% [markdown]
# #### Se infiere que no debe haber unidades negativas, por lo que se le aplica el valor absoluto

# %%
df["Units"] = df["Units"].apply(lambda x: np.absolute(x))
df["Units"].describe().T
# Out:
# count    4004.000000
# mean       97.476523
# std       240.470546
# min         0.000000
# 25%         9.000000
# 50%        28.000000
# 75%        79.250000
# max      3701.000000
# Name: Units, dtype: float64

# %% [markdown]
# #### Se modifica el tipo de dato de la columna "Date"

# %%
df["Date"] = df["Date"].astype("datetime64[ns]")

# %% [markdown]
# #### Se estandarizan las categorias

# %%
df["CATEGORIA"].unique()
# Out:
# array(['Cremas', 'Leches', 'Postres', 'Quesos', 'Yogurt',
#        'AlimentoLiquido', 'AlimentoLIquido', 'Carnicos', 'Crema', 'H&W',
#        'Jugos', 'Leche', 'Queso', 'Reyes', 'Formulas', 'Yoghurt',
#        'Yogurth', 'Fórmulas', 'dic', 'Vita', 'AlimLiq', 'Cuaresma',
#        'Form', 'Lanzamientos', 'Mantequilla', 'SanValentin', 'SuperBowl',
#        'YogurtGriego', 'Aliquido'], dtype=object)

# %%
def eliminar_acentos(text):
    a,b = 'áéíóúü','aeiouu'
    aux = str.maketrans(a,b)
    return text.translate(aux)

def correct_category (text):
    aux = text.lower()
    aux = eliminar_acentos(aux)
    if "yog" in aux:
        return "yogurt"
    elif "liq" in aux:
        return "alimento liquido"
    elif "form" in aux:
        return "formula"
    elif "crem" in aux:
        return "crema"
    elif "queso" in aux:
        return "queso"
    elif "leche" in aux:
        return "leche"
    else:
        return aux
df["CATEGORIA"] = df["CATEGORIA"].apply(lambda x: correct_category(x))

# %%
df = df[df['CATEGORIA'] != 'dic']

# %% [markdown]
# #### Para este caso se dejaran los valores atipicos observados

# %% [markdown]
# ## 4. Eliminar filas duplicadas.

# %% [markdown]
# #### No se encuentran valores duplicados al no existir algun identificador que pudirean sugerirlo

# %%
print(df.shape)
df.drop_duplicates()
df.shape
# Out:
# (3976, 12)
# (3976, 12)

# %% [markdown]
# ## 5. Corregir valores inconsistentes.

# %% [markdown]
# #### Se realizó en el paso 3

# %% [markdown]
# ## 6. Tratar valores nulos.

# %%
df.isna().sum()
# Out:
# RETAIL                0
# CATEGORIA             0
# Date                  0
# Impressions           0
# Clicks                0
# CTR                   0
# Unique Visitors    1134
# Frequency          1134
# Spend                 0
# Units                 0
# Sales                 0
# ROAS                  0
# dtype: int64

# %% [markdown]
# #### Podriamos borrarlos simplemente

# %%
df_without_na = df.dropna()
df_without_na.isna().sum()
# Out:
# RETAIL             0
# CATEGORIA          0
# Date               0
# Impressions        0
# Clicks             0
# CTR                0
# Unique Visitors    0
# Frequency          0
# Spend              0
# Units              0
# Sales              0
# ROAS               0
# dtype: int64

# %% [markdown]
# #### O podriamos llenarlos con alguna metrica como la media

# %%
mean_v = df_without_na["Unique Visitors"].mean()
mean_f = df_without_na["Frequency"].mean()

print (f""" Unique Visitors Mean: {mean_v}
Frequency Mean: {mean_f}
""")

df_fill_with_mean = df.fillna({"Unique Visitors": mean_v, "Frequency": mean_f})
df_fill_with_mean.isna().sum()
# Out:
#  Unique Visitors Mean: 2074.2860661505983
# Frequency Mean: 2.233201794510908
# RETAIL             0
# CATEGORIA          0
# Date               0
# Impressions        0
# Clicks             0
# CTR                0
# Unique Visitors    0
# Frequency          0
# Spend              0
# Units              0
# Sales              0
# ROAS               0
# dtype: int64

# %%
df = df_without_na

# %% [markdown]
# # 7. Cree dos columnas adicionales, dia y mes

# %%
df["Month"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df.head()
# Out:
#   RETAIL CATEGORIA       Date  Impressions  Clicks       CTR  Unique Visitors  \
# 0     BA     crema 2023-07-01         2386      14  0.005868           2391.0
# 1     BA     crema 2023-07-02         3423      17  0.004966           3319.0
# 2     BA     crema 2023-07-03         4241      17  0.004008           4242.0
# 3     BA     crema 2023-07-04         3947      20  0.005067           3913.0
# 4     BA     crema 2023-07-05         3697      19  0.005139           3707.0
#
#    Frequency   Spend  Units   Sales   ROAS  Month  Day
# 0     0.9979  134.40     13   405.0   3.01      7    1
# 1     1.0313  163.20     17   561.5   3.44      7    2
# 2     0.9998  136.32     13   427.5   3.14      7    3
# 3     1.0087  153.60      8   272.0   1.77      7    4
# 4     0.9973  105.72     21  3903.0  36.92      7    5

# %% [markdown]
# ## 8. Cree una columna con convertir las impresiones en miles (000)

# %%
df["New Impressions"] = df["Impressions"].apply(lambda x: x*1000)
df.head()
# Out:
#   RETAIL CATEGORIA       Date  Impressions  Clicks       CTR  Unique Visitors  \
# 0     BA     crema 2023-07-01         2386      14  0.005868           2391.0
# 1     BA     crema 2023-07-02         3423      17  0.004966           3319.0
# 2     BA     crema 2023-07-03         4241      17  0.004008           4242.0
# 3     BA     crema 2023-07-04         3947      20  0.005067           3913.0
# 4     BA     crema 2023-07-05         3697      19  0.005139           3707.0
#
#    Frequency   Spend  Units   Sales   ROAS  Month  Day  New Impressions
# 0     0.9979  134.40     13   405.0   3.01      7    1          2386000
# 1     1.0313  163.20     17   561.5   3.44      7    2          3423000
# 2     0.9998  136.32     13   427.5   3.14      7    3          4241000
# 3     1.0087  153.60      8   272.0   1.77      7    4          3947000
# 4     0.9973  105.72     21  3903.0  36.92      7    5          3697000

# %% [markdown]
# ## 9. Agregar una columna y calcular el Costo por Unidad

# %%
df["Unit Cost"] = df.apply(lambda x: x["Sales"]/x["Units"] if x["Units"] > 0 else 0, axis=1)
df["Unit Cost"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 10. Cree una columna llamada "Best Practice", y si el ROAS (Retorno sobre la Inversión) es mayor a 20, identificar los registros en esta columna como "BP"

# %%
df["Best Practice"] = df["ROAS"].apply(lambda x: "BP" if x >= 20.0 else "No BP") 
df.head()
# Out:
#   RETAIL CATEGORIA       Date  Impressions  Clicks       CTR  Unique Visitors  \
# 0     BA     crema 2023-07-01         2386      14  0.005868           2391.0
# 1     BA     crema 2023-07-02         3423      17  0.004966           3319.0
# 2     BA     crema 2023-07-03         4241      17  0.004008           4242.0
# 3     BA     crema 2023-07-04         3947      20  0.005067           3913.0
# 4     BA     crema 2023-07-05         3697      19  0.005139           3707.0
#
#    Frequency   Spend  Units   Sales   ROAS  Month  Day  New Impressions  \
# 0     0.9979  134.40     13   405.0   3.01      7    1          2386000
# 1     1.0313  163.20     17   561.5   3.44      7    2          3423000
# 2     0.9998  136.32     13   427.5   3.14      7    3          4241000
# 3     1.0087  153.60      8   272.0   1.77      7    4          3947000
# 4     0.9973  105.72     21  3903.0  36.92      7    5          3697000
#
#     Unit Cost Best Practice
# 0   31.153846         No BP
# 1   33.029412         No BP
# 2   32.884615         No BP
# 3   34.000000         No BP
# 4  185.857143            BP

# %% [markdown]
# ## 11. Cree una tabla de datos organizando de mayor a menor, las categorias de esta base.

# %%
df_sorted = df.sort_values(by="CATEGORIA",ascending=False)
df_sorted.head()
# Out:
#      RETAIL CATEGORIA       Date  Impressions  Clicks       CTR  \
# 4003     WM    yogurt 2023-08-11         4139     115  0.027784
# 1645   SAMS    yogurt 2023-01-18          712      35  0.049157
# 942    SAMS    yogurt 2023-02-03         3376      76  0.022512
# 943    SAMS    yogurt 2023-02-04         3751      74  0.019728
# 944    SAMS    yogurt 2023-02-05         3245      74  0.022804
#
#       Unique Visitors  Frequency    Spend  Units    Sales  ROAS  Month  Day  \
# 4003            962.0     4.3025   806.45    155  4396.00  5.45      8   11
# 1645            334.0     2.1317   476.19      3   258.93  0.54      1   18
# 942            1556.0     2.1697  1000.00     14  1423.00  1.42      2    3
# 943            1815.0     2.0667  1000.00     26  2616.10  2.62      2    4
# 944            1579.0     2.0551  1000.00     27  2698.70  2.70      2    5
#
#       New Impressions   Unit Cost Best Practice
# 4003          4139000   28.361290         No BP
# 1645           712000   86.310000         No BP
# 942           3376000  101.642857         No BP
# 943           3751000  100.619231         No BP
# 944           3245000   99.951852         No BP

# %% [markdown]
# ## 12. Cree una tabla con % del gasto total que se invirtió para cada categoría

# %%
total = df["Spend"].sum()
print(total)
df_grouped = df.groupby("CATEGORIA")["Spend"].sum()
df_grouped = df_grouped.apply(lambda x: (x/total)*100)
df_grouped
# Out:
# 2575105.45
# CATEGORIA
# alimento liquido     2.241844
# carnicos             3.546619
# crema               11.260547
# cuaresma             2.169204
# formula              3.053503
# h&w                  0.086297
# jugos                0.078568
# lanzamientos         1.153901
# leche               42.006531
# mantequilla          1.299744
# postres              2.899423
# queso               11.349819
# reyes                3.373018
# sanvalentin          0.183022
# superbowl            0.737835
# vita                 3.013098
# yogurt              11.547028
# Name: Spend, dtype: float64

# %%
px.pie(df_grouped, values="Spend", names=df_grouped.index, title="Porcentaje de gasto por categoría")

# %% [markdown]
# ## 13. Guardar la base de datos transformada.

# %%
df.to_csv('./data/output.csv', index=False)
